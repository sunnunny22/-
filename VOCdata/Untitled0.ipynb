# %%
# !python /content/drive/MyDrive/yolov5-master/VOCdata/xml_to_yolo.py

# %%
# !python /content/drive/MyDrive/yolov5-master/detect.py --weights /content/drive/MyDrive/yolov5-master/runs/train/exp3/weights/best.pt --source /content/drive/MyDrive/yolov5-master/VOCdata/images/003.jpg

# %%
# !python /content/drive/MyDrive/yolov5-master/train.py --weights weights/yolov5s.pt  --cfg /content/drive/MyDrive/yolov5-master/models/yolov5s.yaml  --data /content/drive/MyDrive/yolov5-master/data/myvoc.yaml --epoch 200

# %%
# %pip install -r /content/drive/MyDrive/yolov5-master/requirements.txt
